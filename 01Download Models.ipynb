# %% [markdown]
# # Download fasttext models
#
# * This script download the fasttext pre-trained models in the languages listed in the config.json file.
# * **Note that each model file is around 8G **, and later you will need to unzip those models, using around 15G per model in total (plus the 8G from the zip file that you can delete later)

# %%
# !mkdir vectors

# %%
import json

with open('config.json') as f:
    lang = json.load(f)['langs']

for l in lang:
    print(l)
    # !wget -P vectors/ {'https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.%s.zip' % l}
# Out:
# es
# --2019-05-16 15:26:36--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.es.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 5445405108 (5.1G) [application/zip]
# Saving to: ‘vectors/wiki.es.zip’
#
# wiki.es.zip         100%[===================>]   5.07G  25.1MB/s    in 3m 36s
#
# 2019-05-16 15:30:12 (24.0 MB/s) - ‘vectors/wiki.es.zip’ saved [5445405108/5445405108]
#
# en
# --2019-05-16 15:30:13--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.en.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 10356881291 (9.6G) [application/zip]
# Saving to: ‘vectors/wiki.en.zip’
#
# wiki.en.zip         100%[===================>]   9.65G  25.4MB/s    in 7m 3s
#
# 2019-05-16 15:37:16 (23.4 MB/s) - ‘vectors/wiki.en.zip’ saved [10356881291/10356881291]
#
# fr
# --2019-05-16 15:37:16--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.fr.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 5975701653 (5.6G) [application/zip]
# Saving to: ‘vectors/wiki.fr.zip’
#
# wiki.fr.zip         100%[===================>]   5.56G  25.1MB/s    in 3m 50s
#
# 2019-05-16 15:41:06 (24.8 MB/s) - ‘vectors/wiki.fr.zip’ saved [5975701653/5975701653]
#
# es
# --2019-05-16 15:41:06--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.es.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 5445405108 (5.1G) [application/zip]
# Saving to: ‘vectors/wiki.es.zip.1’
#
# wiki.es.zip.1       100%[===================>]   5.07G  24.1MB/s    in 3m 37s
#
# 2019-05-16 15:44:44 (23.9 MB/s) - ‘vectors/wiki.es.zip.1’ saved [5445405108/5445405108]
#
# ca
# --2019-05-16 15:44:44--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ca.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3857521003 (3.6G) [application/zip]
# Saving to: ‘vectors/wiki.ca.zip’
#
# wiki.ca.zip         100%[===================>]   3.59G  25.1MB/s    in 2m 31s
#
# 2019-05-16 15:47:16 (24.3 MB/s) - ‘vectors/wiki.ca.zip’ saved [3857521003/3857521003]
#
# ar
# --2019-05-16 15:47:16--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ar.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 4243104161 (4.0G) [application/zip]
# Saving to: ‘vectors/wiki.ar.zip’
#
# wiki.ar.zip         100%[===================>]   3.95G  23.2MB/s    in 2m 50s
#
# 2019-05-16 15:50:06 (23.9 MB/s) - ‘vectors/wiki.ar.zip’ saved [4243104161/4243104161]
#
# ru
# --2019-05-16 15:50:06--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ru.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 8344906764 (7.8G) [application/zip]
# Saving to: ‘vectors/wiki.ru.zip’
#
# wiki.ru.zip         100%[===================>]   7.77G  25.6MB/s    in 5m 31s
#
# 2019-05-16 15:55:38 (24.0 MB/s) - ‘vectors/wiki.ru.zip’ saved [8344906764/8344906764]
#
# uk
# --2019-05-16 15:55:38--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.uk.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 5217692977 (4.9G) [application/zip]
# Saving to: ‘vectors/wiki.uk.zip’
#
# wiki.uk.zip         100%[===================>]   4.86G  25.3MB/s    in 3m 32s
#
# 2019-05-16 15:59:10 (23.5 MB/s) - ‘vectors/wiki.uk.zip’ saved [5217692977/5217692977]
#
# pt
# --2019-05-16 15:59:10--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.pt.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 4184487938 (3.9G) [application/zip]
# Saving to: ‘vectors/wiki.pt.zip’
#
# wiki.pt.zip         100%[===================>]   3.90G  25.4MB/s    in 2m 40s
#
# 2019-05-16 16:01:51 (24.9 MB/s) - ‘vectors/wiki.pt.zip’ saved [4184487938/4184487938]
#
# vi
# --2019-05-16 16:01:51--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.vi.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3217489890 (3.0G) [application/zip]
# Saving to: ‘vectors/wiki.vi.zip’
#
# wiki.vi.zip         100%[===================>]   3.00G  24.5MB/s    in 2m 9s
#
# 2019-05-16 16:04:01 (23.7 MB/s) - ‘vectors/wiki.vi.zip’ saved [3217489890/3217489890]
#
# zh
# --2019-05-16 16:04:01--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.zh.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3349374426 (3.1G) [application/zip]
# Saving to: ‘vectors/wiki.zh.zip’
#
# wiki.zh.zip         100%[===================>]   3.12G  25.5MB/s    in 2m 7s
#
# 2019-05-16 16:06:08 (25.2 MB/s) - ‘vectors/wiki.zh.zip’ saved [3349374426/3349374426]
#
# ru
# --2019-05-16 16:06:09--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ru.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 8344906764 (7.8G) [application/zip]
# Saving to: ‘vectors/wiki.ru.zip.1’
#
# wiki.ru.zip.1       100%[===================>]   7.77G  24.8MB/s    in 5m 40s
#
# 2019-05-16 16:11:50 (23.4 MB/s) - ‘vectors/wiki.ru.zip.1’ saved [8344906764/8344906764]
#
# he
# --2019-05-16 16:11:50--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.he.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3850232760 (3.6G) [application/zip]
# Saving to: ‘vectors/wiki.he.zip’
#
# wiki.he.zip         100%[===================>]   3.58G  25.3MB/s    in 2m 26s
#
# 2019-05-16 16:14:16 (25.2 MB/s) - ‘vectors/wiki.he.zip’ saved [3850232760/3850232760]
#
# it
# --2019-05-16 16:14:16--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.it.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 5078091916 (4.7G) [application/zip]
# Saving to: ‘vectors/wiki.it.zip’
#
# wiki.it.zip         100%[===================>]   4.73G  24.5MB/s    in 3m 29s
#
# 2019-05-16 16:17:46 (23.1 MB/s) - ‘vectors/wiki.it.zip’ saved [5078091916/5078091916]
#
# ta
# --2019-05-16 16:17:46--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ta.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3059578743 (2.8G) [application/zip]
# Saving to: ‘vectors/wiki.ta.zip’
#
# wiki.ta.zip         100%[===================>]   2.85G  25.3MB/s    in 2m 47s
#
# 2019-05-16 16:20:34 (17.4 MB/s) - ‘vectors/wiki.ta.zip’ saved [3059578743/3059578743]
#
# id
# --2019-05-16 16:20:34--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.id.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3243640514 (3.0G) [application/zip]
# Saving to: ‘vectors/wiki.id.zip’
#
# wiki.id.zip         100%[===================>]   3.02G  24.0MB/s    in 2m 12s
#
# 2019-05-16 16:22:47 (23.4 MB/s) - ‘vectors/wiki.id.zip’ saved [3243640514/3243640514]
#
# fa
# --2019-05-16 16:22:47--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.fa.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3631863356 (3.4G) [application/zip]
# Saving to: ‘vectors/wiki.fa.zip’
#
# wiki.fa.zip         100%[===================>]   3.38G  25.2MB/s    in 2m 19s
#
# 2019-05-16 16:25:07 (24.9 MB/s) - ‘vectors/wiki.fa.zip’ saved [3631863356/3631863356]
#
# ca
# --2019-05-16 16:25:07--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.ca.zip
# Resolving webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)... 2620:0:861:1:208:80:154:22, 208.80.154.22
# Connecting to webproxy.eqiad.wmnet (webproxy.eqiad.wmnet)|2620:0:861:1:208:80:154:22|:8080... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 3857521003 (3.6G) [application/zip]
# Saving to: ‘vectors/wiki.ca.zip.1’
#
# wiki.ca.zip.1       100%[===================>]   3.59G  25.3MB/s    in 2m 26s
#
# 2019-05-16 16:27:34 (25.1 MB/s) - ‘vectors/wiki.ca.zip.1’ saved [3857521003/3857521003]
